# %% [markdown]
# <a href="https://colab.research.google.com/github/mifm/mifm_test/blob/master/battery_power_zero_bug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://gitlab.windenergy.dtu.dk/TOPFARM/hydesign.git@Megha_P2X_BM_v1_4
# Out:
# Collecting git+https://gitlab.windenergy.dtu.dk/TOPFARM/hydesign.git@Megha_P2X_BM_v1_4
#   Cloning https://gitlab.windenergy.dtu.dk/TOPFARM/hydesign.git (to revision Megha_P2X_BM_v1_4) to /tmp/pip-req-build-j7p_1v32
#   Running command git clone --filter=blob:none --quiet https://gitlab.windenergy.dtu.dk/TOPFARM/hydesign.git /tmp/pip-req-build-j7p_1v32
#   Running command git checkout -b Megha_P2X_BM_v1_4 --track origin/Megha_P2X_BM_v1_4
#   Switched to a new branch 'Megha_P2X_BM_v1_4'
#   Branch 'Megha_P2X_BM_v1_4' set up to track remote branch 'Megha_P2X_BM_v1_4' from 'origin'.
#   Resolved https://gitlab.windenergy.dtu.dk/TOPFARM/hydesign.git to commit 436440f870f2f0d63ff1c3f5a9fcd92e61d4450a
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (2023.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (2.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (1.11.4)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (1.3.0)
# Collecting netcdf4 (from hydesign==1.3.4)
#   Downloading netCDF4-1.7.1.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 44.0 MB/s eta 0:00:00
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (2023.7.0)
# Collecting openmdao (from hydesign==1.3.4)
#   Downloading openmdao-3.33.0.tar.gz (12.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 80.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting smt (from hydesign==1.3.4)
#   Downloading smt-2.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (819 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.2/819.2 kB 56.2 MB/s eta 0:00:00
# Collecting cplex (from hydesign==1.3.4)
#   Downloading cplex-22.1.1.2-cp310-cp310-manylinux1_x86_64.whl (44.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 MB 11.7 MB/s eta 0:00:00
# Collecting docplex (from hydesign==1.3.4)
#   Downloading docplex-2.27.239.tar.gz (635 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.6/635.6 kB 53.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy-financial (from hydesign==1.3.4)
#   Downloading numpy_financial-1.0.0-py3-none-any.whl (14 kB)
# Collecting pvlib (from hydesign==1.3.4)
#   Downloading pvlib-0.11.0-py3-none-any.whl (29.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (0.14.2)
# Collecting rainflow (from hydesign==1.3.4)
#   Downloading rainflow-3.2.0-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (6.0.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from hydesign==1.3.4) (3.7.1)
# Collecting zarr (from hydesign==1.3.4)
#   Downloading zarr-2.18.2-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.2/210.2 kB 25.3 MB/s eta 0:00:00
# Collecting ortools (from hydesign==1.3.4)
#   Downloading ortools-9.10.4067-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 24.1 MB/s eta 0:00:00
# Collecting NREL-PySAM (from hydesign==1.3.4)
#   Downloading NREL_PySAM-5.1.0-cp310-cp310-manylinux2014_x86_64.whl (49.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask->hydesign==1.3.4) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask->hydesign==1.3.4) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask->hydesign==1.3.4) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask->hydesign==1.3.4) (24.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask->hydesign==1.3.4) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask->hydesign==1.3.4) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask->hydesign==1.3.4) (8.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from docplex->hydesign==1.3.4) (1.16.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from h5netcdf->hydesign==1.3.4) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->hydesign==1.3.4) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->hydesign==1.3.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->hydesign==1.3.4) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->hydesign==1.3.4) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->hydesign==1.3.4) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->hydesign==1.3.4) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->hydesign==1.3.4) (2.8.2)
# Collecting cftime (from netcdf4->hydesign==1.3.4)
#   Downloading cftime-1.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.0 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netcdf4->hydesign==1.3.4) (2024.6.2)
# Collecting python-dotenv (from NREL-PySAM->hydesign==1.3.4)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from NREL-PySAM->hydesign==1.3.4) (2.31.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from openmdao->hydesign==1.3.4) (3.3)
# Collecting absl-py>=2.0.0 (from ortools->hydesign==1.3.4)
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 18.3 MB/s eta 0:00:00
# Collecting protobuf>=5.26.1 (from ortools->hydesign==1.3.4)
#   Downloading protobuf-5.27.2-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.3/309.3 kB 32.4 MB/s eta 0:00:00
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from ortools->hydesign==1.3.4) (4.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hydesign==1.3.4) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hydesign==1.3.4) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->hydesign==1.3.4) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->hydesign==1.3.4) (3.5.0)
# Collecting pyDOE3 (from smt->hydesign==1.3.4)
#   Downloading pydoe3-1.0.3-py2.py3-none-any.whl (25 kB)
# Collecting jenn (from smt->hydesign==1.3.4)
#   Downloading jenn-1.0.6-py3-none-any.whl (33 kB)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->hydesign==1.3.4) (0.5.6)
# Collecting asciitree (from zarr->hydesign==1.3.4)
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numcodecs>=0.10.0 (from zarr->hydesign==1.3.4)
#   Downloading numcodecs-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 103.2 MB/s eta 0:00:00
# Collecting fasteners (from zarr->hydesign==1.3.4)
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask->hydesign==1.3.4) (3.19.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask->hydesign==1.3.4) (1.0.0)
# Collecting jsonpointer>=2.4 (from jenn->smt->hydesign==1.3.4)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting jsonschema>=4.22 (from jenn->smt->hydesign==1.3.4)
#   Downloading jsonschema-4.22.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 12.7 MB/s eta 0:00:00
# Collecting orjson>=3.9 (from jenn->smt->hydesign==1.3.4)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->NREL-PySAM->hydesign==1.3.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->NREL-PySAM->hydesign==1.3.4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->NREL-PySAM->hydesign==1.3.4) (2.0.7)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.22->jenn->smt->hydesign==1.3.4) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.22->jenn->smt->hydesign==1.3.4) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.22->jenn->smt->hydesign==1.3.4) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.22->jenn->smt->hydesign==1.3.4) (0.18.1)
# Building wheels for collected packages: hydesign, docplex, openmdao, asciitree
#   Building wheel for hydesign (setup.py) ... done
#   Created wheel for hydesign: filename=hydesign-1.3.4-py3-none-any.whl size=45335359 sha256=971a20e1fe8006fdaad7b57cc0c194fca15629c5ac27f4033fd8ecf4b92cfd88
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4movdxl9/wheels/de/2b/4d/7baed83b943818238fa544324b382a0f4e65ee19cfb2423d05
#   Building wheel for docplex (pyproject.toml) ... done
#   Created wheel for docplex: filename=docplex-2.27.239-py3-none-any.whl size=674503 sha256=7b1f231603a9b38592c12e8267aec5344893ac797679ebba9e7de01e02dc1628
#   Stored in directory: /root/.cache/pip/wheels/62/7c/db/cef9425e1cedbf45621545097eaaeed5efe07005bd8229dd74
#   Building wheel for openmdao (pyproject.toml) ... done
#   Created wheel for openmdao: filename=openmdao-3.33.0-py3-none-any.whl size=13123668 sha256=40e5526fbcada1b9e6508ec95115667a650938dde9f2a792d368487f0218c46d
#   Stored in directory: /root/.cache/pip/wheels/f7/fe/a0/f444187ef7ccf12f29135eba8609d2fa0223840b777c2e379d
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5034 sha256=e3a7e1330232a9ef6697d9525b0ec81f267b41819d3a3216d97f76b351669a3c
#   Stored in directory: /root/.cache/pip/wheels/7f/4e/be/1171b40f43b918087657ec57cf3b81fa1a2e027d8755baa184
# Successfully built hydesign docplex openmdao asciitree
# Installing collected packages: cplex, asciitree, rainflow, python-dotenv, protobuf, orjson, numpy-financial, numcodecs, jsonpointer, fasteners, docplex, cftime, absl-py, zarr, pyDOE3, openmdao, netcdf4, pvlib, ortools, NREL-PySAM, jsonschema, jenn, smt, hydesign
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.19.2
#     Uninstalling jsonschema-4.19.2:
#       Successfully uninstalled jsonschema-4.19.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires protobuf<5,>=3.20, but you have protobuf 5.27.2 which is incompatible.
# google-ai-generativelanguage 0.6.4 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-api-core 2.16.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-aiplatform 1.57.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-bigquery-connection 1.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-bigquery-storage 2.25.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-bigtable 2.24.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-datastore 2.15.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-firestore 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-functions 1.13.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-iam 2.15.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-language 2.13.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-resource-manager 1.12.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-translate 3.11.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# tensorflow 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.27.2 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.27.2 which is incompatible.
# Successfully installed NREL-PySAM-5.1.0 absl-py-2.1.0 asciitree-0.3.3 cftime-1.6.4 cplex-22.1.1.2 docplex-2.27.239 fasteners-0.19 hydesign-1.3.4 jenn-1.0.6 jsonpointer-3.0.0 jsonschema-4.22.0 netcdf4-1.7.1.post1 numcodecs-0.12.1 numpy-financial-1.0.0 openmdao-3.33.0 orjson-3.10.6 ortools-9.10.4067 protobuf-5.27.2 pvlib-0.11.0 pyDOE3-1.0.3 python-dotenv-1.0.1 rainflow-3.2.0 smt-2.6.2 zarr-2.18.2

# %%
import os
import time
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from hydesign.assembly.hpp_assembly_P2X import hpp_model_P2X as hpp_model
from hydesign.examples import examples_filepath

# %%
examples_sites = pd.read_csv(f'{examples_filepath}examples_sites.csv', index_col=0, sep=';')
examples_sites
# Out:
#       case                                          name  longitude  \
# 0    India                         Indian_site_good_wind  77.500226
# 1    India                        Indian_site_good_solar  68.542204
# 2    India                Indian_site_bad_solar_bad_wind  77.916878
# 3   Europe                             France_good_solar   4.229736
# 4   Europe                              France_good_wind  -0.864258
# 5   Europe                       France_bad_solar_n_wind   2.167969
# 6   Europe                      Germany_bad_solar_n_wind  10.766602
# 7   Europe                             Germany_good_wind   7.873535
# 8   Europe                            Denmark_good_solar  11.813965
# 9   Europe                             Denmark_good_wind   8.594398
# 10  Europe                              Denmark_offshore   7.906111
# 11  Europe                          Denmark_good_wind_BM   8.594398
# 12  Europe  Denmark_hybridization_wind_Norhede_Hjortmose   8.366400
# 13  Europe        Denmark_hybridization_solar_Langelinie  11.290641
#
#      latitude    altitude                                        input_ts_fn  \
# 0    8.334294  679.803454      India/GWA2/input_ts_Indian_site_good_wind.csv
# 1   23.542099   29.883557     India/GWA2/input_ts_Indian_site_good_solar.csv
# 2   17.292316  627.424643  India/GWA2/input_ts_Indian_site_bad_solar_bad_...
# 3   44.422011  204.000000         Europe/GWA2/input_ts_France_good_solar.csv
# 4   48.744116  302.000000          Europe/GWA2/input_ts_France_good_wind.csv
# 5   47.428087  140.000000   Europe/GWA2/input_ts_France_bad_solar_n_wind.csv
# 6   49.310798  442.000000  Europe/GWA2/input_ts_Germany_bad_solar_n_wind.csv
# 7   53.287111    5.000000         Europe/GWA2/input_ts_Germany_good_wind.csv
# 8   55.397760   42.000000        Europe/GWA2/input_ts_Denmark_good_solar.csv
# 9   56.227322   85.000000         Europe/GWA2/input_ts_Denmark_good_wind.csv
# 10  55.529722   85.000000          Europe/GWA2/input_ts_Denmark_offshore.csv
# 11  56.227322   85.000000   Europe/GWA2_BM/input_ts_Denmark_good_wind_DA.csv
# 12  56.095400   16.662000  Europe/GWA2/input_ts_Denmark_hybridization_win...
# 13  54.717469    0.042000  Europe/GWA2/input_ts_Denmark_hybridization_sol...
#
#                        sim_pars_fn                       price_fn price_col  \
# 0               India/hpp_pars.yml  India/Indian_elec_price_t.csv     Price
# 1               India/hpp_pars.yml  India/Indian_elec_price_t.csv     Price
# 2               India/hpp_pars.yml  India/Indian_elec_price_t.csv     Price
# 3              Europe/hpp_pars.yml       Europe/2030-EL_PRICE.csv      FR_R
# 4              Europe/hpp_pars.yml       Europe/2030-EL_PRICE.csv      FR_R
# 5              Europe/hpp_pars.yml       Europe/2030-EL_PRICE.csv      FR_R
# 6              Europe/hpp_pars.yml       Europe/2030-EL_PRICE.csv     DE_ME
# 7              Europe/hpp_pars.yml       Europe/2030-EL_PRICE.csv     DE_NW
# 8              Europe/hpp_pars.yml       Europe/2030-EL_PRICE.csv      DK_E
# 9              Europe/hpp_pars.yml       Europe/2030-EL_PRICE.csv      DK_W
# 10    Europe/hpp_pars_offshore.yml       Europe/2030-EL_PRICE.csv      DK_W
# 11             Europe/hpp_pars.yml       Europe/2030-EL_PRICE.csv      DK_W
# 12   Europe/hpp_pars_Hjortmose.yml       Europe/2030-EL_PRICE.csv      DK_W
# 13  Europe/hpp_pars_Langelinie.yml       Europe/2030-EL_PRICE.csv      DK_E
#
#            H2_demand_col  Unnamed: 11  \
# 0    India/H2_demand.csv          NaN
# 1    India/H2_demand.csv          NaN
# 2    India/H2_demand.csv          NaN
# 3   Europe/H2_demand.csv          NaN
# 4   Europe/H2_demand.csv          NaN
# 5   Europe/H2_demand.csv          NaN
# 6   Europe/H2_demand.csv          NaN
# 7   Europe/H2_demand.csv          NaN
# 8   Europe/H2_demand.csv          NaN
# 9   Europe/H2_demand.csv          NaN
# 10  Europe/H2_demand.csv          NaN
# 11  Europe/H2_demand.csv          NaN
# 12  Europe/H2_demand.csv          NaN
# 13  Europe/H2_demand.csv          NaN
#
#                                       input_HA_ts_fn  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11  Europe/GWA2_BM/input_ts_Denmark_good_wind_HA.csv
# 12                                               NaN
# 13                                               NaN
#
#                           price_up_ts                         price_dwn_ts
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# 5                                 NaN                                  NaN
# 6                                 NaN                                  NaN
# 7                                 NaN                                  NaN
# 8                                 NaN                                  NaN
# 9                                 NaN                                  NaN
# 10                                NaN                                  NaN
# 11  Europe/BM_Prices/Up_reg_price.csv  Europe/BM_Prices/Down_reg_price.csv
# 12                                NaN                                  NaN
# 13                                NaN                                  NaN

# %%
name = 'France_good_wind'

ex_site = examples_sites.loc[examples_sites.name == name]

longitude = ex_site['longitude'].values[0]
latitude = ex_site['latitude'].values[0]
altitude = ex_site['altitude'].values[0]

# %%
# Weather data and Price data
input_ts_fn = examples_filepath+ex_site['input_ts_fn'].values[0]

input_ts = pd.read_csv(input_ts_fn, index_col=0, parse_dates=True)

required_cols = [col for col in input_ts.columns if 'WD' not in col]
input_ts = input_ts.loc[:,required_cols]
input_ts
# Out:
#                          WS_1     WS_50     WS_100     WS_150     WS_200  \
# 2012-01-01 00:00:00  3.816262  9.189450  11.084209  12.271178  13.193283
# 2012-01-01 01:00:00  3.433942  8.425198  10.193588  11.295483  12.177159
# 2012-01-01 02:00:00  3.401840  8.457382  10.257751  11.500057  12.475967
# 2012-01-01 03:00:00  3.552851  8.750878  10.595812  11.846432  12.862474
# 2012-01-01 04:00:00  3.563602  8.849321  10.730704  12.023872  13.075707
# ...                       ...       ...        ...        ...        ...
# 2012-12-30 19:00:00  3.431328  8.738007  10.644316  11.514788  12.815824
# 2012-12-30 20:00:00  3.522005  8.956219  10.906332  11.806788  13.153907
# 2012-12-30 21:00:00  3.546788  9.081438  11.071820  12.064809  13.412334
# 2012-12-30 22:00:00  3.613134  9.352224  11.424145  12.542857  13.966094
# 2012-12-30 23:00:00  3.672954  9.526146  11.639926  12.831741  14.247031
#
#                      temp_air_1      ghi  dni      dhi   Price
# 2012-01-01 00:00:00  284.873662  0.10670  0.0  0.10670  32.685
# 2012-01-01 01:00:00  284.759079  0.05335  0.0  0.05335  32.685
# 2012-01-01 02:00:00  284.682409  0.00000  0.0  0.00000  32.685
# 2012-01-01 03:00:00  284.804835  0.00000  0.0  0.00000  32.685
# 2012-01-01 04:00:00  284.912742  0.00000  0.0  0.00000  32.685
# ...                         ...      ...  ...      ...     ...
# 2012-12-30 19:00:00  281.205509  0.00000  0.0  0.00000  37.591
# 2012-12-30 20:00:00  281.139846  0.00000  0.0  0.00000  35.839
# 2012-12-30 21:00:00  280.716650  0.00000  0.0  0.00000  35.362
# 2012-12-30 22:00:00  280.646177  0.00000  0.0  0.00000  34.468
# 2012-12-30 23:00:00  280.627905  0.00000  0.0  0.00000  33.417
#
# [8760 rows x 10 columns]

# %%
# Hydrogen demand data, when H2 offtake is infinite -> make H2_demand values very high (1e6) in H2_demand.csv file and penalty_H2 as '0' in hpp_pars.yml file
H2_demand_fn = examples_filepath+ex_site['H2_demand_col'].values[0]

H2_demand_ts = pd.read_csv(H2_demand_fn, index_col=0, parse_dates=True)
H2_demand_ts
# Out:
#                      H2_demand
# 2012-01-01 00:00:00      10000
# 2012-01-01 01:00:00      10000
# 2012-01-01 02:00:00      10000
# 2012-01-01 03:00:00      10000
# 2012-01-01 04:00:00      10000
# ...                        ...
# 2012-12-31 19:00:00      10000
# 2012-12-31 20:00:00      10000
# 2012-12-31 21:00:00      10000
# 2012-12-31 22:00:00      10000
# 2012-12-31 23:00:00      10000
#
# [8784 rows x 1 columns]

# %%
# Input data of technology's cost
sim_pars_fn = examples_filepath+ex_site['sim_pars_fn'].values[0]

with open(sim_pars_fn) as file:
    sim_pars = yaml.load(file, Loader=yaml.FullLoader)

print(sim_pars_fn)
sim_pars
# Out:
# /usr/local/lib/python3.10/dist-packages/hydesign/examples/Europe/hpp_pars.yml
# {'G_MW': 300,
#  'year': '2012',
#  'N_life': 25,
#  'wind_turbine_cost': 640000,
#  'wind_civil_works_cost': 260000,
#  'wind_fixed_onm_cost': 12600,
#  'wind_variable_onm_cost': 1.35,
#  'd_ref': 145,
#  'hh_ref': 100,
#  'p_rated_ref': 5.0,
#  'wpp_efficiency': 1,
#  'wind_deg_yr': [0, 25],
#  'wind_deg': [0, 0.25],
#  'share_WT_deg_types': 0.5,
#  'solar_PV_cost': 110000,
#  'solar_hardware_installation_cost': 100000,
#  'solar_inverter_cost': 20000,
#  'solar_fixed_onm_cost': 4500,
#  'land_use_per_solar_MW': 0.01226,
#  'tracking': 'No',
#  'pv_deg_yr': [0, 1, 25],
#  'pv_deg': [0.03, 0.03, 0.28],
#  'battery_energy_cost': 62000,
#  'battery_power_cost': 16000,
#  'battery_BOP_installation_commissioning_cost': 80000,
#  'battery_control_system_cost': 2250,
#  'battery_energy_onm_cost': 0,
#  'battery_depth_of_discharge': 0.9,
#  'battery_charge_efficiency': 0.985,
#  'battery_price_reduction_per_year': 0.05,
#  'min_LoH': 0.7,
#  'n_full_power_hours_expected_per_day_at_peak_price': 0,
#  'peak_hr_quantile': 0.9,
#  'price_H2': 5,
#  'storage_eff': 0.9,
#  'ptg_deg': 0.99,
#  'hhv': 39.3,
#  'water_consumption': 9.4,
#  'electrolyzer_capex_cost': 800000,
#  'electrolyzer_opex_cost': 16000,
#  'electrolyzer_power_electronics_cost': 0,
#  'water_cost': 4,
#  'water_treatment_cost': 2,
#  'H2_storage_capex_cost': 300,
#  'H2_storage_opex_cost': 3,
#  'H2_transportation_cost': 5,
#  'H2_transportation_distance': 0,
#  'penalty_factor_H2': 0,
#  'electrolyzer_eff_curve_name': 'PEM electrolyzer H2 production',
#  'min_power_standby': 0.02,
#  'ramp_up_limit': 50,
#  'ramp_down_limit': 50,
#  'hpp_BOS_soft_cost': 119940,
#  'hpp_grid_connection_cost': 50000,
#  'land_cost': 300000,
#  'wind_WACC': 0.06,
#  'solar_WACC': 0.06,
#  'battery_WACC': 0.06,
#  'tax_rate': 0.22,
#  'ptg_WACC': 0.08,
#  'phasing_yr': [-1, 0],
#  'phasing_CAPEX': [1, 1],
#  'inflation_yr': [-3, 0, 1, 25],
#  'inflation': [0.1, 0.1, 0.06, 0.06],
#  'ref_yr_inflation': 0,
#  'depreciation_yr': [0, 25],
#  'depreciation': [0, 1],
#  'bi_directional_status': 0,
#  'penalty_BM': 2000,
#  'era5_zarr': '/groups/reanalyses/era5/app/era5.zarr',
#  'ratio_gwa_era5': '/groups/INP/era5/ratio_gwa2_era5.nc',
#  'era5_ghi_zarr': '/groups/INP/era5/ghi.zarr',
#  'elevation_fn': '/groups/INP/era5/SRTMv3_plus_ViewFinder_coarsen.nc'}

# %%
hpp = hpp_model(
        latitude,
        longitude,
        altitude,
        num_batteries = 3,
        work_dir = './',
        sim_pars_fn = sim_pars_fn,
        input_ts_fn = input_ts_fn,
        H2_demand_fn = H2_demand_fn,
)
# Out:
# Fixed parameters on the site
# -------------------------------
# longitude = -0.864258
# latitude = 48.744116
# altitude = 302.0

# %%
start = time.time()

clearance = 10
sp = 360
p_rated = 4
Nwt = 90
wind_MW_per_km2 = 5
solar_MW = 80
surface_tilt = 50
surface_azimuth = 210
DC_AC_ratio = 1.5
b_P = 0
b_E_h  = 4
cost_of_batt_degr = 10
ptg_MW = 150
HSS_kg = 3000

x = [clearance, sp, p_rated, Nwt, wind_MW_per_km2, solar_MW, surface_tilt, surface_azimuth, DC_AC_ratio, b_P, b_E_h, cost_of_batt_degr, ptg_MW, HSS_kg]

outs = hpp.evaluate(*x)

hpp.print_design(x, outs)

end = time.time()
print(f'exec. time [min]:', (end - start)/60 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/openmdao/core/system.py in _call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2665         try:
# -> 2666             yield
#    2667         except Exception:
#
# /usr/local/lib/python3.10/dist-packages/openmdao/core/explicitcomponent.py in _compute_wrapper(self)
#     266                 else:
# --> 267                     self.compute(self._inputs, self._outputs)
#     268
#
# /usr/local/lib/python3.10/dist-packages/hydesign/ems/ems_P2X.py in compute(self, inputs, outputs)
#     284
# --> 285         P_HPP_ts, P_curtailment_ts, P_charge_discharge_ts, P_ptg_ts, P_ptg_SB_ts, E_SOC_ts, m_H2_ts, m_H2_offtake_ts, LoS_H2_ts, penalty_ts = ems_WSB(
#     286             wind_ts = WSPr_df.wind_t,
#
# /usr/local/lib/python3.10/dist-packages/hydesign/ems/ems_P2X.py in ems_cplex_P2X(wind_ts, solar_ts, price_ts, P_batt_MW, E_batt_MWh_t, hpp_grid_connection, battery_depth_of_discharge, charge_efficiency, price_H2, ptg_MW, HSS_kg, storage_eff, ptg_deg, hhv, m_H2_demand_ts, H2_storage_t, penalty_factor_H2, eff_curve, min_power_standby, load_min_penalty_factor, peak_hr_quantile, cost_of_battery_P_fluct_in_peak_price_ratio, n_full_power_hours_expected_per_day_at_peak_price, batch_size)
#     399         P_HPP_ts_batch, P_curtailment_ts_batch, P_charge_discharge_ts_batch, P_ptg_ts_batch, P_ptg_SB_ts_batch,\
# --> 400         E_SOC_ts_batch, m_H2_ts_batch, m_H2_offtake_ts_batch, LoS_H2_ts_batch, penalty_batch = ems_cplex_parts_P2X(
#     401             wind_ts = wind_ts_sel,
#
# /usr/local/lib/python3.10/dist-packages/hydesign/ems/ems_P2X.py in ems_cplex_parts_P2X(wind_ts, solar_ts, price_ts, P_batt_MW, E_batt_MWh_t, hpp_grid_connection, battery_depth_of_discharge, charge_efficiency, price_H2, ptg_MW, HSS_kg, storage_eff, ptg_deg, hhv, m_H2_demand_ts, H2_storage_t, penalty_factor_H2, eff_curve, min_power_standby, load_min_penalty_factor, peak_hr_quantile, cost_of_battery_P_fluct_in_peak_price_ratio, n_full_power_hours_expected_per_day_at_peak_price)
#     670
# --> 671     P_HPP_ts_df = pd.DataFrame.from_dict(sol.get_value_dict(P_HPP_t), orient='index').loc[:,0]
#     672     P_curtailment_ts_df = pd.DataFrame.from_dict(sol.get_value_dict(P_curtailment_t), orient='index').loc[:,0]
#
# AttributeError: 'NoneType' object has no attribute 'get_value_dict'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-feed421b67ad> in <cell line: 20>()
#      18 x = [clearance, sp, p_rated, Nwt, wind_MW_per_km2, solar_MW, surface_tilt, surface_azimuth, DC_AC_ratio, b_P, b_E_h, cost_of_batt_degr, ptg_MW, HSS_kg]
#      19
# ---> 20 outs = hpp.evaluate(*x)
#      21
#      22 hpp.print_design(x, outs)
#
# /usr/local/lib/python3.10/dist-packages/hydesign/assembly/hpp_assembly_P2X.py in evaluate(self, clearance, sp, p_rated, Nwt, wind_MW_per_km2, solar_MW, surface_tilt, surface_azimuth, DC_AC_ratio, b_P, b_E_h, cost_of_battery_P_fluct_in_peak_price_ratio, ptg_MW, HSS_kg)
#     664         prob.set_val('cost_of_battery_P_fluct_in_peak_price_ratio',cost_of_battery_P_fluct_in_peak_price_ratio)
#     665
# --> 666         prob.run_model()
#     667
#     668         self.prob = prob
#
# /usr/local/lib/python3.10/dist-packages/openmdao/core/problem.py in run_model(self, case_prefix, reset_iter_counts)
#     675
#     676             self.model._clear_iprint()
# --> 677             self.model.run_solve_nonlinear()
#     678         finally:
#     679             self._recording_iter.prefix = old_prefix
#
# /usr/local/lib/python3.10/dist-packages/openmdao/core/system.py in run_solve_nonlinear(self)
#    4680         """
#    4681         with self._scaled_context_all():
# -> 4682             self._solve_nonlinear()
#    4683
#    4684     def run_apply_linear(self, mode, scope_out=None, scope_in=None):
#
# /usr/local/lib/python3.10/dist-packages/openmdao/core/group.py in _solve_nonlinear(self)
#    3456         with Recording(name + '._solve_nonlinear', self.iter_count, self):
#    3457             with self._relevance.active(self._nonlinear_solver.use_relevance()):
# -> 3458                 self._nonlinear_solver._solve_with_cache_check()
#    3459
#    3460         # Iteration counter is incremented in the Recording context manager at exit.
#
# /usr/local/lib/python3.10/dist-packages/openmdao/solvers/nonlinear/nonlinear_runonce.py in _solve_with_cache_check(self)
#      24
#      25     def _solve_with_cache_check(self):
# ---> 26         self.solve()  # don't use caching
#      27
#      28     def solve(self):
#
# /usr/local/lib/python3.10/dist-packages/openmdao/solvers/nonlinear/nonlinear_runonce.py in solve(self)
#      43             # If this is not a parallel group, transfer for each subsystem just prior to running it.
#      44             else:
# ---> 45                 self._gs_iter()
#      46
#      47             rec.abs = 0.0
#
# /usr/local/lib/python3.10/dist-packages/openmdao/solvers/solver.py in _gs_iter(self)
#     863             if subsys._is_local:
#     864                 try:
# --> 865                     subsys._solve_nonlinear()
#     866                 except AnalysisError as err:
#     867                     if 'reraise_child_analysiserror' not in self.options or \
#
# /usr/local/lib/python3.10/dist-packages/openmdao/core/explicitcomponent.py in _solve_nonlinear(self)
#     291             with self._unscaled_context(outputs=[self._outputs], residuals=[self._residuals]):
#     292                 self._residuals.set_val(0.0)
# --> 293                 self._compute_wrapper()
#     294
#     295             # Iteration counter is incremented in the Recording context manager at exit.
#
# /usr/local/lib/python3.10/dist-packages/openmdao/core/explicitcomponent.py in _compute_wrapper(self)
#     245         Call compute based on the value of the "run_root_only" option.
#     246         """
# --> 247         with self._call_user_function('compute'):
#     248             if self._run_root_only():
#     249                 if self.comm.rank == 0:
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     151                 value = typ()
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#     155                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.10/dist-packages/openmdao/core/system.py in _call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2670                 raise
#    2671             else:
# -> 2672                 raise err_type(
#    2673                     f"{self.msginfo}: Error calling {fname}(), {err}").with_traceback(trace)
#    2674         finally:
#
# /usr/local/lib/python3.10/dist-packages/openmdao/core/system.py in _call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2664
#    2665         try:
# -> 2666             yield
#    2667         except Exception:
#    2668             err_type, err, trace = sys.exc_info()
#
# /usr/local/lib/python3.10/dist-packages/openmdao/core/explicitcomponent.py in _compute_wrapper(self)
#     265                                  self._discrete_inputs, self._discrete_outputs)
#     266                 else:
# --> 267                     self.compute(self._inputs, self._outputs)
#     268
#     269     def _apply_nonlinear(self):
#
# /usr/local/lib/python3.10/dist-packages/hydesign/ems/ems_P2X.py in compute(self, inputs, outputs)
#     283         #print(WSPr_df.head())
#     284
# --> 285         P_HPP_ts, P_curtailment_ts, P_charge_discharge_ts, P_ptg_ts, P_ptg_SB_ts, E_SOC_ts, m_H2_ts, m_H2_offtake_ts, LoS_H2_ts, penalty_ts = ems_WSB(
#     286             wind_ts = WSPr_df.wind_t,
#     287             solar_ts = WSPr_df.solar_t,
#
# /usr/local/lib/python3.10/dist-packages/hydesign/ems/ems_P2X.py in ems_cplex_P2X(wind_ts, solar_ts, price_ts, P_batt_MW, E_batt_MWh_t, hpp_grid_connection, battery_depth_of_discharge, charge_efficiency, price_H2, ptg_MW, HSS_kg, storage_eff, ptg_deg, hhv, m_H2_demand_ts, H2_storage_t, penalty_factor_H2, eff_curve, min_power_standby, load_min_penalty_factor, peak_hr_quantile, cost_of_battery_P_fluct_in_peak_price_ratio, n_full_power_hours_expected_per_day_at_peak_price, batch_size)
#     398         #print(f'batch {ib+1} out of {len(batches)}')
#     399         P_HPP_ts_batch, P_curtailment_ts_batch, P_charge_discharge_ts_batch, P_ptg_ts_batch, P_ptg_SB_ts_batch,\
# --> 400         E_SOC_ts_batch, m_H2_ts_batch, m_H2_offtake_ts_batch, LoS_H2_ts_batch, penalty_batch = ems_cplex_parts_P2X(
#     401             wind_ts = wind_ts_sel,
#     402             solar_ts = solar_ts_sel,
#
# /usr/local/lib/python3.10/dist-packages/hydesign/ems/ems_P2X.py in ems_cplex_parts_P2X(wind_ts, solar_ts, price_ts, P_batt_MW, E_batt_MWh_t, hpp_grid_connection, battery_depth_of_discharge, charge_efficiency, price_H2, ptg_MW, HSS_kg, storage_eff, ptg_deg, hhv, m_H2_demand_ts, H2_storage_t, penalty_factor_H2, eff_curve, min_power_standby, load_min_penalty_factor, peak_hr_quantile, cost_of_battery_P_fluct_in_peak_price_ratio, n_full_power_hours_expected_per_day_at_peak_price)
#     669     #sol.display()
#     670
# --> 671     P_HPP_ts_df = pd.DataFrame.from_dict(sol.get_value_dict(P_HPP_t), orient='index').loc[:,0]
#     672     P_curtailment_ts_df = pd.DataFrame.from_dict(sol.get_value_dict(P_curtailment_t), orient='index').loc[:,0]
#     673     P_charge_discharge_ts_df = pd.DataFrame.from_dict(sol.get_value_dict(P_charge_discharge), orient='index').loc[:,0]
#
# AttributeError: 'ems' <class ems_P2X>: Error calling compute(), 'NoneType' object has no attribute 'get_value_dict'
